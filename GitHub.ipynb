# %%
# Задание №1:

# Если взять ВСЕ числа от 0 до 10, которые деляться на 3 или 5 БЕЗ ОСТАТКА, то получим 3, 5, 6 и 9. 

for i in range(1,10):
    if i%3==0 or i%5==0:
        print(i)

# Сумма этих чисел равна 23 (3+5+6+9) = 23.
a = [x for x in range(1,10) if x%3==0 or x%5==0]
print(sum(a))

# Найдите сумму всех чисел меньше 1000, кратных 3 или 5.


a = [x for x in range(1,1000) if x%3==0 or x%5==0]
print(sum(a))
# Out:
# 3
# 5
# 6
# 9
# 23
# 233168

# %%
# Задание №2:
# a = 333
# b = 555
# Поменяйте значения переменных местами(НЕ ВРУЧНУЮ!), 
#чтобы в ПЕРЕМЕННОЙ "a" было значение 555, а в ПЕРМЕННОЙ "b" было значение 333.
a = 333
b = 555
a,b=b,a
print("a",a)
print("b",b)
# Out:
# a 555
# b 333

# %%
# Задание №3:
# Если взять строку - "237" и сложить все её числа то получится 2+3+7 = 12.

a = "237"
sum=0
for i in  a:
    sum+=int(i)
print(sum)


# Возьмите строку "4729461084" и сложите все её числа.
a = "4729461084"
sum1=0
for l in  a:
    sum1+=int(l)
print(sum1)

# Результат выведите на экран.
print("string '237' равен:", sum)
print("string '4729461084' равен:", sum1)
# Out:
# 12
# 45
# string '237' равен: 12
# string '4729461084' равен: 45

# %%
# Задание №4:
# Создайте input() который принимает от пользователя дату в формате: "2020-10-24 18:30" 
#и возвращает dictionary разделённую по значениям даты:

# date = {
# "year": "2020",
# "month": "10",
# .....
# }

print("задание 4")
data = '2022/06/29 12:30'
time = data.split(" ")[1]
new_data = data.split(" ")[0].split("/")
print(new_data.extend(time))
data_dict = {}
data_dict["год"] = new_data[0]
data_dict["месяц"] = new_data[1]
data_dict["день"] = new_data[2]
data_dict["время"] = time
print(data_dict)

# %%
# Задание №5:
# Какое слово нужно сложить 5 раз чтобы получить число 5?
# Какое слово нужно умножить на 7 чтобы получить 7?

print(True+True+True+True+True)
print(True*7)
# Out:
# 5
# 7

# %%
# Задание №6:
# Напишите команду Linux которая создаст ДИРЕКТОРИЮ в НЕСУЩЕСТВУЮЩЕЙ директории БЕЗ ОШИБОК!

mkdir newFold

# %%
# Задание №7:
# Как в Linux выглядит полный путь до Desktop Директории для пользователя 'developer'.
/home/sainakan
